# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/Users/gageholcomb/Desktop/DDA13/Python/projects/wego-salzburg/data/Headway Data.csv')

# %%
performance = pd.DataFrame(data[['ADHERENCE_ID', 'ADHERENCE', 'ACTUAL_ARRIVAL_TIME', 'ACTUAL_DEPARTURE_TIME', 'ADJUSTED_ONTIME_COUNT']])

# %%
performance = performance.loc[performance['ADJUSTED_ONTIME_COUNT'] == 1]

# %%
performance
# Out:
#         ADHERENCE_ID  ADHERENCE  ACTUAL_ARRIVAL_TIME ACTUAL_DEPARTURE_TIME  \
# 0           99457890  -2.133333  2023-08-01 04:37:38   2023-08-01 04:44:08
# 1           99457891  -2.450000  2023-08-01 04:48:27   2023-08-01 04:48:27
# 2           99457892  -0.933333  2023-08-01 04:54:56   2023-08-01 04:54:56
# 3           99457893   6.283333  2023-08-01 05:03:43   2023-08-01 05:03:43
# 4           99457894  -1.583333  2023-08-01 05:03:43   2023-08-01 05:16:35
# ...              ...        ...                  ...                   ...
# 350315     100406601  -3.333333  2023-09-30 21:02:20   2023-09-30 21:02:20
# 350316     100406602  -1.666666  2023-09-30 21:12:40   2023-09-30 21:12:40
# 350317     100406603  -0.850000  2023-09-30 21:12:40   2023-09-30 21:16:51
# 350320     100406606  -5.900000  2023-09-30 21:43:52   2023-09-30 21:50:54
# 350326     100406612  -4.316666  2023-09-30 22:49:19   2023-09-30 22:49:19
#
#         ADJUSTED_ONTIME_COUNT
# 0                           1
# ...

# %%
performance['ADHERENCE'].mean()
# Out:
# -1.490594007902299

# %%
performance['ADHERENCE'].max()
# Out:
# 34.716666

# %%
performance['ADHERENCE'].min()
# Out:
# -6.0

# %%
performance['ADHERENCE'].nlargest(n=5)
# Out:
# 178699    34.716666
# 288085    33.750000
# 24549     33.350000
# 162481    32.916666
# 327793    32.333333
# Name: ADHERENCE, dtype: float64

# %%
performance['ADHERENCE'].nsmallest(n=5)
# Out:
# 1463   -6.0
# 2025   -6.0
# 3881   -6.0
# 3935   -6.0
# 4060   -6.0
# Name: ADHERENCE, dtype: float64

# %%
performance
# Out:
#         ADHERENCE_ID  ADHERENCE  ACTUAL_ARRIVAL_TIME ACTUAL_DEPARTURE_TIME  \
# 0           99457890  -2.133333  2023-08-01 04:37:38   2023-08-01 04:44:08
# 1           99457891  -2.450000  2023-08-01 04:48:27   2023-08-01 04:48:27
# 2           99457892  -0.933333  2023-08-01 04:54:56   2023-08-01 04:54:56
# 3           99457893   6.283333  2023-08-01 05:03:43   2023-08-01 05:03:43
# 4           99457894  -1.583333  2023-08-01 05:03:43   2023-08-01 05:16:35
# ...              ...        ...                  ...                   ...
# 350315     100406601  -3.333333  2023-09-30 21:02:20   2023-09-30 21:02:20
# 350316     100406602  -1.666666  2023-09-30 21:12:40   2023-09-30 21:12:40
# 350317     100406603  -0.850000  2023-09-30 21:12:40   2023-09-30 21:16:51
# 350320     100406606  -5.900000  2023-09-30 21:43:52   2023-09-30 21:50:54
# 350326     100406612  -4.316666  2023-09-30 22:49:19   2023-09-30 22:49:19
#
#         ADJUSTED_ONTIME_COUNT
# 0                           1
# ...

# %%
plt.boxplot(performance['ADHERENCE'], vert = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1493cedd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1493f9150>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1493eec90>],
#  'medians': [<matplotlib.lines.Line2D at 0x1493fa8d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1493fb410>],
#  'means': []}

# %%
#Question 2 by Direction

# %%
direction = pd.read_csv('/Users/gageholcomb/Desktop/DDA13/Python/projects/wego-salzburg/data/Headway Data.csv')

# %%
direction.columns
# Out:
# Index(['CALENDAR_ID', 'SERVICE_ABBR', 'ADHERENCE_ID', 'DATE', 'ROUTE_ABBR',
#        'BLOCK_ABBR', 'OPERATOR', 'TRIP_ID', 'OVERLOAD_ID',
#        'ROUTE_DIRECTION_NAME', 'TIME_POINT_ABBR', 'ROUTE_STOP_SEQUENCE',
#        'TRIP_EDGE', 'LATITUDE', 'LONGITUDE', 'SCHEDULED_TIME',
#        'ACTUAL_ARRIVAL_TIME', 'ACTUAL_DEPARTURE_TIME', 'ADHERENCE',
#        'SCHEDULED_HDWY', 'ACTUAL_HDWY', 'HDWY_DEV', 'ADJUSTED_EARLY_COUNT',
#        'ADJUSTED_LATE_COUNT', 'ADJUSTED_ONTIME_COUNT', 'STOP_CANCELLED',
#        'PREV_SCHED_STOP_CANCELLED', 'IS_RELIEF', 'DWELL_IN_MINS',
#        'SCHEDULED_LAYOVER_MINUTES'],
#       dtype='object')

# %%
direction = pd.DataFrame(data[['ROUTE_DIRECTION_NAME', 'ADJUSTED_EARLY_COUNT', 'ADJUSTED_LATE_COUNT', 'ADJUSTED_ONTIME_COUNT', 'ADHERENCE']])

# %%
direction
# Out:
#        ROUTE_DIRECTION_NAME  ADJUSTED_EARLY_COUNT  ADJUSTED_LATE_COUNT  \
# 0               TO DOWNTOWN                     0                    0
# 1               TO DOWNTOWN                     0                    0
# 2               TO DOWNTOWN                     0                    0
# 3               TO DOWNTOWN                     0                    0
# 4             FROM DOWNTOWN                     0                    0
# ...                     ...                   ...                  ...
# 350324          TO DOWNTOWN                     0                    1
# 350325          TO DOWNTOWN                     0                    1
# 350326        FROM DOWNTOWN                     0                    0
# 350327        FROM DOWNTOWN                     0                    1
# 350328        FROM DOWNTOWN                     0                    1
#
#         ADJUSTED_ONTIME_COUNT  ADHERENCE
# 0                           1  -2.133333
# ...

# %%
#Adherence Comparison

# %%
to_downtown = direction.loc[direction['ROUTE_DIRECTION_NAME'] == 'TO DOWNTOWN']

# %%
to_downtown['ADHERENCE'].mean()
# Out:
# -2.3218044230829493

# %%
x = to_downtown['ADHERENCE'].mean()

# %%
from_downtown = direction.loc[direction['ROUTE_DIRECTION_NAME'] == 'FROM DOWNTOWN']

# %%
from_downtown['ADHERENCE'].mean()
# Out:
# -3.960287122712012

# %%
y = from_downtown['ADHERENCE'].mean()

# %%
x - y
# Out:
# 1.638482699629063

# %%
#OnTime Comparison

# %%
to_downtown[['ADJUSTED_ONTIME_COUNT', 'ADJUSTED_EARLY_COUNT', 'ADJUSTED_LATE_COUNT']].sum()
# Out:
# ADJUSTED_ONTIME_COUNT    135634
# ADJUSTED_EARLY_COUNT       4484
# ADJUSTED_LATE_COUNT       19437
# dtype: int64

# %%
to_sum = to_downtown[['ADJUSTED_ONTIME_COUNT', 'ADJUSTED_EARLY_COUNT', 'ADJUSTED_LATE_COUNT']].sum()

# %%
to_sum.sum()
# Out:
# 159555

# %%
to_downtown['ADJUSTED_ONTIME_COUNT'].sum()/to_sum.sum()
# Out:
# 0.8500767760333428

# %%
from_downtown[['ADJUSTED_ONTIME_COUNT', 'ADJUSTED_EARLY_COUNT', 'ADJUSTED_LATE_COUNT']].sum()
# Out:
# ADJUSTED_ONTIME_COUNT    134414
# ADJUSTED_EARLY_COUNT       5291
# ADJUSTED_LATE_COUNT       39601
# dtype: int64

# %%
from_sum = from_downtown[['ADJUSTED_ONTIME_COUNT', 'ADJUSTED_EARLY_COUNT', 'ADJUSTED_LATE_COUNT']].sum()

# %%
from_sum.sum()
# Out:
# 179306

# %%
from_downtown['ADJUSTED_ONTIME_COUNT'].sum()/from_sum.sum()
# Out:
# 0.7496347026870267

# %%
# Coming from downtown is worse performance, lower ontime percentage and later adherence

# %%
to_ontimes = np.array([135634, 4484, 19437])
tolabels = ["Ontime - 85%", "Early", "Late"]
plt.pie(to_ontimes, labels = tolabels, shadow = True)
plt.title("Ontime Ratio - To Downtown")
plt.show()
plt.savefig('Ontime.png')

# %%
from_ontimes = np.array([134414, 5291, 39601])
fromlabels = ["Ontime - 74.9%", "Early", "Late"]
myexplode = [0.2, 0, 0, 0]
plt.pie(from_ontimes, labels = fromlabels, shadow = True)
plt.title("Ontime Ratio - From Downtown")
plt.show()

# %%
to_downtown['ADHERENCE'].describe()
# Out:
# count    159555.000000
# mean         -2.321804
# std           6.391098
# min        -618.166666
# 25%          -3.666666
# 50%          -1.500000
# 75%          -0.100000
# max          88.383333
# Name: ADHERENCE, dtype: float64

# %%
from_downtown['ADHERENCE'].describe()
# Out:
# count    179306.000000
# mean         -3.960287
# std           7.234279
# min        -948.533333
# 25%          -5.466666
# 50%          -2.516666
# 75%          -0.633333
# max          76.766666
# Name: ADHERENCE, dtype: float64

# %%
#Question 3

# %%
route_time = pd.read_csv('/Users/gageholcomb/Desktop/DDA13/Python/projects/wego-salzburg/data/Headway Data.csv')

# %%
route_time
# Out:
#         CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0         120230801             1      99457890  2023-08-01          22
# 1         120230801             1      99457891  2023-08-01          22
# 2         120230801             1      99457892  2023-08-01          22
# 3         120230801             1      99457893  2023-08-01          22
# 4         120230801             1      99457894  2023-08-01          22
# ...             ...           ...           ...         ...         ...
# 350324    120230930             2     100406610  2023-09-30           7
# 350325    120230930             2     100406611  2023-09-30           7
# 350326    120230930             2     100406612  2023-09-30           7
# 350327    120230930             2     100406613  2023-09-30           7
# 350328    120230930             2     100406614  2023-09-30           7
#
#         BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
route_time.columns
# Out:
# Index(['CALENDAR_ID', 'SERVICE_ABBR', 'ADHERENCE_ID', 'DATE', 'ROUTE_ABBR',
#        'BLOCK_ABBR', 'OPERATOR', 'TRIP_ID', 'OVERLOAD_ID',
#        'ROUTE_DIRECTION_NAME', 'TIME_POINT_ABBR', 'ROUTE_STOP_SEQUENCE',
#        'TRIP_EDGE', 'LATITUDE', 'LONGITUDE', 'SCHEDULED_TIME',
#        'ACTUAL_ARRIVAL_TIME', 'ACTUAL_DEPARTURE_TIME', 'ADHERENCE',
#        'SCHEDULED_HDWY', 'ACTUAL_HDWY', 'HDWY_DEV', 'ADJUSTED_EARLY_COUNT',
#        'ADJUSTED_LATE_COUNT', 'ADJUSTED_ONTIME_COUNT', 'STOP_CANCELLED',
#        'PREV_SCHED_STOP_CANCELLED', 'IS_RELIEF', 'DWELL_IN_MINS',
#        'SCHEDULED_LAYOVER_MINUTES'],
#       dtype='object')

# %%
route_time = pd.DataFrame(route_time[['ROUTE_DIRECTION_NAME','ADHERENCE_ID', 'ADHERENCE', 'ACTUAL_ARRIVAL_TIME', 'ACTUAL_DEPARTURE_TIME', 'ADJUSTED_ONTIME_COUNT']])

# %%
route_time
# Out:
#        ROUTE_DIRECTION_NAME  ADHERENCE_ID  ADHERENCE  ACTUAL_ARRIVAL_TIME  \
# 0               TO DOWNTOWN      99457890  -2.133333  2023-08-01 04:37:38
# 1               TO DOWNTOWN      99457891  -2.450000  2023-08-01 04:48:27
# 2               TO DOWNTOWN      99457892  -0.933333  2023-08-01 04:54:56
# 3               TO DOWNTOWN      99457893   6.283333  2023-08-01 05:03:43
# 4             FROM DOWNTOWN      99457894  -1.583333  2023-08-01 05:03:43
# ...                     ...           ...        ...                  ...
# 350324          TO DOWNTOWN     100406610  -8.433333  2023-09-30 22:31:26
# 350325          TO DOWNTOWN     100406611 -11.300000  2023-09-30 22:49:18
# 350326        FROM DOWNTOWN     100406612  -4.316666  2023-09-30 22:49:19
# 350327        FROM DOWNTOWN     100406613 -22.083333  2023-09-30 23:21:05
# 350328        FROM DOWNTOWN     100406614 -23.666666  2023-09-30 23:31:27
#
#        ACTUAL_DEPARTURE_TIME  ADJUSTED_ONTIME_COUNT
# ...

# %%
rt_to = direction.loc[route_time['ROUTE_DIRECTION_NAME'] == 'TO DOWNTOWN']

# %%
rt_from = direction.loc[route_time['ROUTE_DIRECTION_NAME'] == 'FROM DOWNTOWN']

# %%
rt_to
# Out:
#        ROUTE_DIRECTION_NAME  ADJUSTED_EARLY_COUNT  ADJUSTED_LATE_COUNT  \
# 0               TO DOWNTOWN                     0                    0
# 1               TO DOWNTOWN                     0                    0
# 2               TO DOWNTOWN                     0                    0
# 3               TO DOWNTOWN                     0                    0
# 7               TO DOWNTOWN                     0                    0
# ...                     ...                   ...                  ...
# 350318          TO DOWNTOWN                     0                    1
# 350319          TO DOWNTOWN                     0                    0
# 350323          TO DOWNTOWN                     0                    1
# 350324          TO DOWNTOWN                     0                    1
# 350325          TO DOWNTOWN                     0                    1
#
#         ADJUSTED_ONTIME_COUNT  ADHERENCE
# 0                           1  -2.133333
# ...

# %%
# Question 4

# %%
data
# Out:
#         CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0         120230801             1      99457890  2023-08-01          22
# 1         120230801             1      99457891  2023-08-01          22
# 2         120230801             1      99457892  2023-08-01          22
# 3         120230801             1      99457893  2023-08-01          22
# 4         120230801             1      99457894  2023-08-01          22
# ...             ...           ...           ...         ...         ...
# 350324    120230930             2     100406610  2023-09-30           7
# 350325    120230930             2     100406611  2023-09-30           7
# 350326    120230930             2     100406612  2023-09-30           7
# 350327    120230930             2     100406613  2023-09-30           7
# 350328    120230930             2     100406614  2023-09-30           7
#
#         BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
driver = pd.DataFrame(data[['OPERATOR', 'ADHERENCE']])

# %%
driver
# Out:
#         OPERATOR  ADHERENCE
# 0           1040  -2.133333
# 1           1040  -2.450000
# 2           1040  -0.933333
# 3           1040   6.283333
# 4           1040  -1.583333
# ...          ...        ...
# 350324      2312  -8.433333
# 350325      2312 -11.300000
# 350326      2312  -4.316666
# 350327      2312 -22.083333
# 350328      2312 -23.666666
#
# [350329 rows x 2 columns]

# %%
driver = driver.groupby(['OPERATOR']).mean()

# %%
driver.describe()
# Out:
#         ADHERENCE
# count  341.000000
# mean    -3.446736
# std      2.649127
# min    -22.066666
# 25%     -4.351053
# 50%     -3.147859
# 75%     -1.935147
# max      8.916666

# %%
driver = driver.reset_index()

# %%
sns.stripplot(x='OPERATOR', y='ADHERENCE', data=driver,
              jitter=True, linewidth=0.5).set(title='Adherence by Operator')
sns.set_style('white')
plt.xticks(visible=False)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
driver_time = pd.DataFrame(data[['OPERATOR', 'ADJUSTED_EARLY_COUNT', 'ADJUSTED_LATE_COUNT', 'ADJUSTED_ONTIME_COUNT']])

# %%
driver_time
# Out:
#         OPERATOR  ADJUSTED_EARLY_COUNT  ADJUSTED_LATE_COUNT  \
# 0           1040                     0                    0
# 1           1040                     0                    0
# 2           1040                     0                    0
# 3           1040                     0                    0
# 4           1040                     0                    0
# ...          ...                   ...                  ...
# 350324      2312                     0                    1
# 350325      2312                     0                    1
# 350326      2312                     0                    0
# 350327      2312                     0                    1
# 350328      2312                     0                    1
#
#         ADJUSTED_ONTIME_COUNT
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           1
# ...                       ...
# ...

# %%
driver_time.describe()
# Out:
#             OPERATOR  ADJUSTED_EARLY_COUNT  ADJUSTED_LATE_COUNT  \
# count  350329.000000         350329.000000        350329.000000
# mean     1951.130514              0.027902             0.168522
# std       769.827675              0.164693             0.374329
# min         0.000000              0.000000             0.000000
# 25%      1391.000000              0.000000             0.000000
# 50%      2012.000000              0.000000             0.000000
# 75%      2585.000000              0.000000             0.000000
# max      3173.000000              1.000000             1.000000
#
#        ADJUSTED_ONTIME_COUNT
# count          350329.000000
# mean                0.770841
# std                 0.420292
# min                 0.000000
# 25%                 1.000000
# 50%                 1.000000
# 75%                 1.000000
# max                 1.000000

# %%
driver_time = driver_time.groupby(['OPERATOR']).sum()

# %%
driver_ontime = driver_time.sort_values(by=['ADJUSTED_ONTIME_COUNT'], ascending = False)

# %%
driver_ontime = driver_ontime.rename(columns={'OPERATOR' : 'Operator', 'ADJUSTED_ONTIME_COUNT' : 'ONTIME', 'ADJUSTED_EARLY_COUNT' : 'EARLY', 'ADJUSTED_LATE_COUNT' : 'LATE'})

# %%
driver_ontime.head(10)
# Out:
#           EARLY  LATE  ONTIME
# OPERATOR
# 1266         75   268    2522
# 1133         13   107    2505
# 1147        159    88    2439
# 1927         38    58    2317
# 409           9    61    2310
# 1762         16    23    2294
# 379          31    56    2172
# 304           3   275    2155
# 2352        216   241    2148
# 2424         46   325    2146

# %%
driver_late = driver_time.sort_values(by=['ADJUSTED_LATE_COUNT'], ascending = False)

# %%
driver_late = driver_late.rename(columns={'OPERATOR' : 'Operator', 'ADJUSTED_ONTIME_COUNT' : 'ONTIME', 'ADJUSTED_EARLY_COUNT' : 'EARLY', 'ADJUSTED_LATE_COUNT' : 'LATE'})

# %%
driver_late.head(10)
# Out:
#           EARLY  LATE  ONTIME
# OPERATOR
# 2109         18   936    1139
# 1800         26   810     789
# 1204         15   767    1336
# 3064         22   750    1113
# 1352         11   728     954
# 2082          7   724    1028
# 2312         16   714     582
# 3101         19   699     579
# 357          35   683     866
# 2783         54   595     706

# %%
driver_early = driver_time.sort_values(by=['ADJUSTED_EARLY_COUNT'], ascending = False)

# %%
driver_early = driver_early.rename(columns={'OPERATOR' : 'Operator', 'ADJUSTED_ONTIME_COUNT' : 'ONTIME', 'ADJUSTED_EARLY_COUNT' : 'EARLY', 'ADJUSTED_LATE_COUNT' : 'LATE'})

# %%
driver_early.head(10)
# Out:
#           EARLY  LATE  ONTIME
# OPERATOR
# 659         379    44    1492
# 2112        234   136    1199
# 2352        216   241    2148
# 1170        187    13    1923
# 1730        181    20     460
# 1761        178    31    1917
# 1717        178    50    1259
# 1361        162   158    1567
# 2230        161    54     969
# 1147        159    88    2439

# %%
#Question 5

# %%
headway = pd.read_csv('/Users/gageholcomb/Desktop/DDA13/Python/projects/wego-salzburg/data/Headway Data.csv')

# %%
headway.columns
# Out:
# Index(['CALENDAR_ID', 'SERVICE_ABBR', 'ADHERENCE_ID', 'DATE', 'ROUTE_ABBR',
#        'BLOCK_ABBR', 'OPERATOR', 'TRIP_ID', 'OVERLOAD_ID',
#        'ROUTE_DIRECTION_NAME', 'TIME_POINT_ABBR', 'ROUTE_STOP_SEQUENCE',
#        'TRIP_EDGE', 'LATITUDE', 'LONGITUDE', 'SCHEDULED_TIME',
#        'ACTUAL_ARRIVAL_TIME', 'ACTUAL_DEPARTURE_TIME', 'ADHERENCE',
#        'SCHEDULED_HDWY', 'ACTUAL_HDWY', 'HDWY_DEV', 'ADJUSTED_EARLY_COUNT',
#        'ADJUSTED_LATE_COUNT', 'ADJUSTED_ONTIME_COUNT', 'STOP_CANCELLED',
#        'PREV_SCHED_STOP_CANCELLED', 'IS_RELIEF', 'DWELL_IN_MINS',
#        'SCHEDULED_LAYOVER_MINUTES'],
#       dtype='object')

# %%
headway = pd.DataFrame(data[['HDWY_DEV', 'ADHERENCE', 'ADJUSTED_LATE_COUNT']])

# %%
headway
# Out:
#          HDWY_DEV  ADHERENCE  ADJUSTED_LATE_COUNT
# 0             NaN  -2.133333                    0
# 1             NaN  -2.450000                    0
# 2             NaN  -0.933333                    0
# 3             NaN   6.283333                    0
# 4             NaN  -1.583333                    0
# ...           ...        ...                  ...
# 350324   5.266666  -8.433333                    1
# 350325        NaN -11.300000                    1
# 350326   1.866666  -4.316666                    0
# 350327  17.500000 -22.083333                    1
# 350328        NaN -23.666666                    1
#
# [350329 rows x 3 columns]

# %%
headway = headway.loc[headway['ADJUSTED_LATE_COUNT'] == 1]

# %%
del headway['ADJUSTED_LATE_COUNT']

# %%
headway
# Out:
#          HDWY_DEV  ADHERENCE
# 69            NaN -12.583333
# 78       4.683333  -6.166666
# 83      -3.983334  -7.266666
# 91       4.166666  -6.516666
# 92       5.816666  -6.733333
# ...           ...        ...
# 350323   4.916666  -8.616666
# 350324   5.266666  -8.433333
# 350325        NaN -11.300000
# 350327  17.500000 -22.083333
# 350328        NaN -23.666666
#
# [59038 rows x 2 columns]

# %%
headway
# Out:
#          HDWY_DEV  ADHERENCE
# 69            NaN -12.583333
# 78       4.683333  -6.166666
# 83      -3.983334  -7.266666
# 91       4.166666  -6.516666
# 92       5.816666  -6.733333
# ...           ...        ...
# 350323   4.916666  -8.616666
# 350324   5.266666  -8.433333
# 350325        NaN -11.300000
# 350327  17.500000 -22.083333
# 350328        NaN -23.666666
#
# [59038 rows x 2 columns]

# %%
headway.corr()
# Out:
#            HDWY_DEV  ADHERENCE
# HDWY_DEV   1.000000  -0.018835
# ADHERENCE -0.018835   1.000000

# %%
headway.describe()
# Out:
#            HDWY_DEV     ADHERENCE
# count  45831.000000  59038.000000
# mean       4.536930    -11.906603
# std        9.675441     12.213734
# min      -64.000000   -948.533333
# 25%        0.666666    -13.100000
# 50%        5.033333     -9.200000
# 75%        8.083333     -7.250000
# max      508.700000     -6.016666

# %%
headway= headway.dropna()

# %%
headway
# Out:
#          HDWY_DEV  ADHERENCE
# 78       4.683333  -6.166666
# 83      -3.983334  -7.266666
# 91       4.166666  -6.516666
# 92       5.816666  -6.733333
# 94       7.316666  -7.083333
# ...           ...        ...
# 350312   5.516666  -6.216666
# 350318   3.566666  -7.000000
# 350323   4.916666  -8.616666
# 350324   5.266666  -8.433333
# 350327  17.500000 -22.083333
#
# [45831 rows x 2 columns]

# %%
sns.regplot(x = "ADHERENCE", y = "HDWY_DEV", data=headway,
            scatter_kws = {"color": "black", "alpha": .3, "s":5}, 
            line_kws = {"color": "red"})
plt.title("Adherence, Headway Deviation Correlation")
plt.savefig('correlation.png', bbox_inches='tight')
